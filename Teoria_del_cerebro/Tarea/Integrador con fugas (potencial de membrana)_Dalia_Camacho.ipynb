# %% [markdown]
# # Integrador con fugas y disparo

# %% [markdown]
# ## Instalación de bibliotecas
#
# Se deben instalar las bibliotecas brian2 y neurodynex utilizando los siguientes comandos en Anaconda:

# %% [raw]
# conda install -c conda-forge brian2
# conda install -c brian-team -c epfl-lcn neurodynex

# %% [markdown]
# ## Bibliotecas a utilizar

# %%
import brian2 as b2

from neurodynex.leaky_integrate_and_fire import LIF
from neurodynex.tools import input_factory
from neurodynex.tools import plot_tools

# %matplotlib inline

# %% [markdown]
# ## Simulación

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 1

# %% [markdown]
# ### Cambiar amplitud (i_min)

# %%
i_min=10.00*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 9

# %% [markdown]
# Si la amplitud i_min aumenta, el número de disparos aumenta

# %% [markdown]
# ### Cambiar firing threshold

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -10*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 0

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -78*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm.
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 19

# %% [markdown]
# Si el firing threshhold disminuye hay más disparos.

# %% [markdown]
# ### Cambiar membrane time scale

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 5.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 2

# %% [markdown]
# Si el time scale de la membrana disminuye el número de disparos aumenta

# %% [markdown]
# ### Cambiar membrane_resistance

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 10.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 8

# %% [markdown]
#  Si la resistencia de la memebrana aumenta el número de disparos aumenta.

# %% [markdown]
# ### Cambiar refractory period

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 1.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 1

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 50.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 1

# %% [markdown]
# Si el refractory period disminuye el número de disparos aumenta.

# %% [markdown]
# ### Cambiar v_rest

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -30*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 11

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -100*b2.mV,
                                                       v_reset               = -80*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 0

# %% [markdown]
# Si v_rest aumenta, el número de disparos aumenta.

# %% [markdown]
# ### Cambiar v_reset

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -20*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 10

# %%
i_min=4.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -50*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 8.*b2.ms,
                                                       membrane_resistance   = 5.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 5.*b2.ms,
                                                       v_rest                = -70*b2.mV,
                                                       v_reset               = -100*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 1

# %% [markdown]
# Si el  v_reset aumenta, aumenta el número de disparos.

# %% [markdown]
#  ### Resumen
#  Para aumentar el número de disparos habría que:
#  1. Aumentar la amplitud
#  2. Disminuir el time scale de la membrana
#  3. Aumentar la resistencia de la membrana
#  4. Disminuir el periodo refractario
#  5. Aumentar v_rest
#  6. Aumentar v_reset

# %%
i_min=10.01*b2.namp

# create a step current with amplitude= i_min
step_current = input_factory.get_step_current(t_start=5, t_end=100, unit_time=b2.ms,amplitude= i_min)  # set i_min to your value

LIF.FIRING_THRESHOLD = -10*b2.mV

# run the LIF model.
# Note: As we do not specify any model parameters, the simulation runs with the default values
(state_monitor,spike_monitor) = LIF.simulate_LIF_neuron(input_current        = step_current, 
                                                       simulation_time       = 100 * b2.ms,
                                                       membrane_time_scale   = 2.*b2.ms,
                                                       membrane_resistance   = 10.*b2.Mohm,
                                                       firing_threshold      = LIF.FIRING_THRESHOLD,
                                                       abs_refractory_period = 0.1*b2.ms,
                                                       v_rest                = -20*b2.mV,
                                                       v_reset               = -20*b2.mV)
# plot I and vm
plot_tools.plot_voltage_and_current_traces(state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)

print("nr of spikes: {}".format(spike_monitor.count[0]))  # should be 0
# Out:
# nr of spikes: 316
